# %% [markdown]
# # PDF loader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("data/dummy.pdf")

docs = loader.load()

print(len(docs))  # number of pages

print(docs[0].page_content[:500])
print(docs[0].metadata)
# Out:
# 1
# Sample Document for PDF Testing
# Introduction
# This is a simple document created to test basic PDF functionality. It includes various text formatting
# options to ensure proper rendering in PDF readers.
# Text Formatting Examples
# 1. Bold text is used for emphasis.
# 2. Italic text can be used for titles or subtle emphasis.
# 3. Strikethrough is used to show deleted text.
# Lists
# Here's an example of an unordered list:
# Item 1
# Item 2
# Item 3
# And here's an ordered list:
# 1. First item
# 2. Second item
# 3. Third ite
# {'producer': 'Skia/PDF m126', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36', 'creationdate': '2024-07-09T13:31:41+00:00', 'title': 'Sample Document for PDF Testing', 'moddate': '2024-07-09T13:31:41+00:00', 'source': 'data/dummy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %% [markdown]
# # TextLoader

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data/data.txt")

docs = loader.load()

print(docs)
print(docs[0].page_content)
# Out:
# [Document(metadata={'source': 'data/data.txt'}, page_content='LangChain is a framework for building applications powered by large language models.\n\nIt provides tools for prompt management, document loading, retrieval, and chaining multiple components together.\n\nDevelopers commonly use LangChain to build systems such as chatbots, question-answering systems, and AI assistants.\n\nOne of the most popular architectures built with LangChain is Retrieval Augmented Generation (RAG), where external documents are retrieved and provided as context to the LLM before generating an answer.\n\nLangChain supports integrations with many model providers including OpenAI, Ollama, Anthropic, and others.\n\nThe framework also includes utilities for building agents that can reason about tasks and interact with external tools such as APIs, databases, and search engines.')]
# LangChain is a framework for building applications powered by large language models.
#
# It provides tools for prompt management, document loading, retrieval, and chaining multiple components together.
#
# Developers commonly use LangChain to build systems such as chatbots, question-answering systems, and AI assistants.
#
# One of the most popular architectures built with LangChain is Retrieval Augmented Generation (RAG), where external documents are retrieved and provided as context to the LLM before generating an answer.
#
# LangChain supports integrations with many model providers including OpenAI, Ollama, Anthropic, and others.
#
# The framework also includes utilities for building agents that can reason about tasks and interact with external tools such as APIs, databases, and search engines.

# %% [markdown]
# # Directory Loader

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader

loader = DirectoryLoader(
    path="data",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
)
documents = loader.load()

print(len(documents))
print(documents[0].page_content)
# Out:
# 1
# Sample Document for PDF Testing
# Introduction
# This is a simple document created to test basic PDF functionality. It includes various text formatting
# options to ensure proper rendering in PDF readers.
# Text Formatting Examples
# 1. Bold text is used for emphasis.
# 2. Italic text can be used for titles or subtle emphasis.
# 3. Strikethrough is used to show deleted text.
# Lists
# Here's an example of an unordered list:
# Item 1
# Item 2
# Item 3
# And here's an ordered list:
# 1. First item
# 2. Second item
# 3. Third item
# Quote
# This is an example of a block quote. It can be used to highlight important information or
# citations.
# Table
# Header 1 Header 2 Header 3
# Row 1, Col 1 Row 1, Col 2 Row 1, Col 3
# Row 2, Col 1 Row 2, Col 2 Row 2, Col 3
# This document demonstrates various formatting options that should translate well to PDF format.
# This sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resources.

# %% [markdown]
# # CSV Loader

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path="data/employees.csv")

documents = loader.load()

print("Total documents:", len(documents))

print("\nFirst document content:\n")
print(documents[0].page_content)

print("\nMetadata:\n")
print(documents[0].metadata)
# Out:
# Total documents: 4
#
# First document content:
#
# id: 1
# name: Alice
# department: Engineering
# salary: 90000
#
# Metadata:
#
# {'source': 'data/employees.csv', 'row': 0}

# %% [markdown]
# # Lazy Loading

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("data/dummy.pdf")

for page in loader.lazy_load():
    print(page.metadata["page"])
# Out:
# 0
